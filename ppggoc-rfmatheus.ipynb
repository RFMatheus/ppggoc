# %%
"""
Tópicos Especiais em GET II: Representações Distribuídas de Texto e Modelagem de Tópicos 
Prof. Renato Rocha de Souza
Prof. Mauricio Barcellos Almeida 
Profa. Renata Maria Abrantes Baracho Porto

UFMG/ECI/PPGGOC 
TGI853 

Aluno: Renato Fabiano Matheus, versão 20171006~0653-0825-20171203~2148

Impresso para entrega ao professor responsável em 20171006~0905
Entregue como notebook Anaconda em 20171205 via GitHub

PROJETO FINAL
Comparação de heurísticas de classificação supervisionada de textos da Web usando técnicas de aprendizado de máquina e feedback 
de usuário para modelagem de texto (text modeling) e agrupamento (clustering)

INTRODUÇÃO
Classificação e categorização são problemas essenciais na Ciência da Informação. Neste projeto esses problemas são tratados com 
a utilização de métodos de classificação [semi-]automática utilizando-se um ambiente de desenvolvimento Python/Anaconda/Jupyter. 
A Seção Referências indica as referências essenciais relacionadas a esta implementação específica. Este projeto foi apresentado 
como requisito da disciplina indicada no cabeçalho, sob orientação do professor Renato Rocha de Souza.  

Problema
Geração [semi-automática][?] de categorias a partir de textos selecionados na Web

Requisitos essenciais
Repositório GitHub para projeto
1 notebooks Python funcionando. Neste projeto são indicados vários, como forma de organização do projeto, mas o essencial 
como requisito para disciplina será criar apenas um notebook que implemente uma das heurísticas indicadas ou outra mais 
apropriada que surja durante desenvolvimento do projeto. 

Data de entrega 
5 de dezembro de 2017 

Requisitos de implementação
Mesmo fazendo a implementação apenas para a língua portuguesa, parametrizar para que módulos sejam multilíngua no caso de 
busca por palavras específicas ou identificação de radical das palavras, por exemplo. 

Convenções de marcação 
? Dúvida
* Requisito necessário 
<variável ou referência a ser substituída>
[<comentários, marcações ou elemento opcional>]
<elemento 1> | <elemento 2> | .. | N Elementos alternativos 

Metadados 
Área de pesquisa e concentração ? CI/Categorização (semi-)automática de textos 
Plataforma: Python/Anaconda/Jupyter
Protótipo da implementação
* Para finalidade dos requisitos da disciplina, a implementação de apenas um dos métodos a seguir será suficiente
Notebook SimpleClassificator [NOTEBOOK ESSENCIAL DO PROJETO]

TRABALHOS FUTUROS 
Criar um estudo de usuário para permitir que várias pessoas selecionem o melhor método de classificação e para o algoritmo 
considerar o somatório dessas escolas como parâmetros a fim de definir melhor método 

Todas as outras funções de classificação usadas pelo métodos de heurística (HeuristicsBagOfWords, HeuristicsVector, 
HeuristicsEntities) poderão ser implementadas com métodos dinâmicos que poderão ser acrescidos à biblioteca do sistema 
ou passadas como parâmetro, em conjunto com seletor binário BestHeuristicsbyUserInteraction.

De acordo com arrayURL os métodos de coleta deverão fazer coleta usando protocolo HTTP ou API específicas (exemplo Twitter). 
Outras ideias para implementação 
* Extraído de anotação de aula

[#rfm #ideiaparasistema Criar um dicionário de assuntos a partir de descrições de classes DDC e inferir assunto de 
documento a partir de similaridade de documento com as classes = assuntos prédefinidos, em 20171003~1552]

[#rfm #ideiaparasistema Expandir dicionários de assuntos original incluindo nos mesmos variações e sinônimos de palavras 
em 20171003~1554
Buscar similaridade entre textos de entrada e dicionário de assuntos 
#motivação: #20171003~1552] 

[#rfm #ideiaparasistema A partir do dicionário expandido, criar um identificador automático de ocorrências de PESSOAS, 
DOCUMENTOS, SISTEMAS, GRUPOS, ORGANIZAÇÕES EVENTOS em documentos usados como entrada
#motivação: #20171003~1554]

[#rfm #ideiaparasistema Usar similaridade entre documentos e entre parágrafos de documentos a fim de identificar tópicos 
relacionado  subtópicos, respectivamente, em 20171003~1633] 
…
[#ideiaparasistema 20171006~0857
Geração de navegador por categorias automático usando cluster
Geração de sugestões de leitura 
] 
Referências 
Diferença entre classificação e categorização [?]
Texto caracterização objetiva de gêneros literários 
“Inventor text modeling, David Blei = https://www.google.com.br/search?q=david+blei 
https://scholar.google.com/citations?user=8OYE6iEAAAAJ&hl=pt-BR 
“Artigo elin jacob classification and categorization pdf

"""

# Método HeuristicsBagOfWords
# Recebe conjunto de links URL para páginas Web, faz coleta e classificação de textos 
# em categorias. Usa seletor binário HeuristicSelected (inicialmente em 0) para 
# determinar método de corte utilizado na passada. 
# HeuristicSelected, entre outras coisas, recebe parâmetro sobre método de nomeação de 
# categorias identificas, sendo que a nomeação pode ser pela identificação de expressões
# (neste caso, a BagOfWords deve armazenar o texto com serializado, com a posição original
# das palavras, a fim de se permitir que se encontre a palavra anterior e a seguinte). 
# PARAMETROS 
# opcional: arrayURL, caso seja do twitter, serão usadas API específicas no lugar e 
# harvesting HTML
# De acordo com <HarvestingMethod> 
# coleta apenas página principal|todo o domínio|todas as páginas linkadas até profundidade N.
# RDFdataset: parâmetro contém indicação da melhor heurística de acordo com seleção 
# do usuário na IHM. Arquivo RDF armazenará as combinações de heurística utilizadas em
# um seletor binário 
# HeuristicSelected: seletor binário de heurística: valorizar primeiras palavras e últimas da 
# frase|parágrafo | eleminar palavras curtas | valorizar palavras que têm poucas 
# ocorrências TFIDF | busca identificar expressões ou palavras como nomes das categorias | ...
HeuristicsBagOfWords( IN arrayURL, 
                      IN HarvestingMethod,
                      OUT TextAndCategories, 
                      IN HeuristicSelected, 
                      IN/OUT RDFdataset BestHeuristicsbyUserInteraction 
                    )

# Método HeurísticsSimilarityVector
# Recebe um conjunto de textos como entrada e busca identificar diferentes gêneros 
# literários a partir de características do texto (e.g. tamanho das frases; presença ou não de 
# Seções e.g., ‘Introdução | Introduction | …’; similaridade entre vocabulário [?]; língua [?])
# A cada passada cria e atribui características ao texto de entrada.
# Infere categorias a partir de combinações das características usando vetor de similaridades
# com cada característica correspondendo a um vetor ortogonal do espaço vetorial 
# PARAMETROS 
# O usuário ou outro programa/heurística pode ser usado para calibrar a melhor 
# categorização (opcional classe UserFeedBack) por isso o método poderá criar uma 
# memória auxiliar contendo a BestHeuristicsbyUserInteraction, conforme seleção.
HeurísticsSimilarityVector( IN arrayURL, IN HarvestingMethod, OUT TextAndCategories, IN/OUT RDFdataset BestHeuristicsbyUserInteraction )  

# Método HeuristicsEntities
# Extrai nomes de categorias e instâncias a partir do texto, usando como base um
# conjunto de entidades prédeterminados PDSGOEDAL+P+A+O+F+$+!+?+...
# Para cada uma das entidades do acrònimo um conjunto de heurísticas poderá ser utilizado
# a fim de associar o texto com a categoria. A interação com usuário permitirá selecioinar as 
# melhores heurísticas
HeurísticsEntities( IN arrayURL, IN HarvestingMethod, OUT TextAndCategories, IN/OUT RDFdataset BestHeuristicsbyUserInteraction )  

Artefatos/heurísticas (protótipo) 
Notebook Classe ‘HTMLProcessing’.Método clean|coleta(arrayURL, heurítica( <somente principal>, <recursivo>)) [opcional: métodos de apoio]

#  Heurísticas indicam: qual método de limpeza de stop words, artigos, etc | quantas 
# palavras devem ser selecionadas por texto | se será data maior prioridade para 
# palavras nas primeiras frases | …. 
# PARAMETROS 
# Heurística1..N: seletor binário que permite indicar ao método o conjunto de heurísticas usado,
# entre eles: descarta flexão nominal e verbal, inferindo radical das palavras; 
Notebook Classe ‘TextProcessing’ (ou mylibTextAnalysis).
Método clean( Heurística1..N, Calibrator ) [opcional: métodos de apoio]
Método tokenizer 
Notebook IHMClassificator [opcional: interação e interface com usuário]
HeuristicsBagOfWords( IN arrayURL, IN HarvestingMethod OUT TextAndCategories)
IHMClassificator.ClassifyVector( IN arrayURL, IN HarvestingMethod, OUT TextAndCategories) 
IHMClassificator.Training( IN ArrayTextAndCategories[0..N], OUT UserChoice )
Heurística: perguntar: Qual label melhor representa o conjunto de textos a direita 
Interface: à esquerda checkbox com os nomes das categorias inferidos, para selecionar

UserFeedBack( IN ArrayTextAndCategories[0..N], IN BestCategory, OUT RDFdataset BestHeuristicsbyUserInteraction )
# Out:
# 3
